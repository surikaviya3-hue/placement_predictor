# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("placement.csv")
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
x=df[['cgpa','placement_exam_marks']]
y=df[['placed']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2)

# %%
print("--------X_train--------")
print(x_train)
print("--------y_train--------")
print(y_train)
# Out:
# --------X_train--------
#      cgpa  placement_exam_marks
# 774  6.93                  69.0
# 400  6.00                  33.0
# 637  7.25                  74.0
# 658  7.57                   9.0
# 646  7.38                  45.0
# ..    ...                   ...
# 208  7.25                  12.0
# 63   6.22                  26.0
# 377  6.70                  47.0
# 557  6.47                  25.0
# 90   7.61                  15.0
#
# [800 rows x 2 columns]
# --------y_train--------
#      placed
# 774       0
# 400       1
# 637       0
# 658       0
# 646       1
# ..      ...
# 208       1
# 63        0
# 377       1
# 557       0
# 90        1
#
# [800 rows x 1 columns]

# %%
print("--------X_test--------")
print(x_test)
print("--------y_test--------")
print(y_test)
# Out:
# --------X_test--------
#      cgpa  placement_exam_marks
# 42   7.46                  71.0
# 319  7.53                  13.0
# 719  7.17                  26.0
# 241  7.22                  18.0
# 242  5.99                  44.0
# ..    ...                   ...
# 910  7.82                  29.0
# 70   6.98                  17.0
# 554  6.84                   9.0
# 947  6.49                  70.0
# 702  6.24                  39.0
#
# [200 rows x 2 columns]
# --------y_test--------
#      placed
# 42        1
# 319       0
# 719       0
# 241       0
# 242       0
# ..      ...
# 910       1
# 70        1
# 554       1
# 947       0
# 702       0
#
# [200 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
pred=model.predict([[8.5, 90]])
pred
# Out:
# c:\Users\kavya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.52328494]])

# %%
import pickle

with open("placement_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
if pred[0] >= 0.5:
    print("Placed")
else:
    print("Not Placed")
# Out:
# Placed
